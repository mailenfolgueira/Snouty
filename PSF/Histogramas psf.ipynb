# %% [markdown]
# ## Láser verde

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import curve_fit


n=[-15, -10, -8, -4, -2, -1, 0, 1, 2, 4, 8, 10, 15]



filename = "C:/Users/Usuario/Documents/Facultad/Laboratorio 7/PSF/list_data_0_deskewed-1_locs.txt"
data = pd.read_csv(filename, sep=" ", header=None)

#Data pasada de px a nm

pixel_size = 127

n_bins = 10

x = data[1] * pixel_size
y = data[2] * pixel_size
sx = data[4] * pixel_size
sy = data[5] * pixel_size


# Function to fit a Gaussian distribution to data
def fit_gaussian(data):
    mu, std = norm.fit(data)
    return mu, std

mu_1 = fit_gaussian(sx)[0]
sigma_1 = fit_gaussian(sx)[1]


def gaussiana(x, mu, sigma):
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)

hist,bins=np.histogram(sx,density=True,bins=n_bins)
bin_centers = (bins[:-1] + bins[1:]) / 2


p,cov=curve_fit(gaussiana,bin_centers,hist,p0=(mu_1,sigma_1))
mu,sigma=p



FWHM = 2 * np.sqrt(2 * np.log(2)) * mu
print(FWHM)
print(2 * np.sqrt(2 * np.log(2)) * sigma)
#print(mu)
#print(sigma)
# Out:
# 424.81835953884024
# 28.685035031398606

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import curve_fit


n=[-15, -10, -8, -4, -2, -1, 0, 1, 2, 4, 8, 10, 15]



filename = "C:/Users/Usuario/Documents/Facultad/Laboratorio 7/PSF/list_data_0_deskewed-1_locs.txt"
data = pd.read_csv(filename, sep=" ", header=None)

#Data pasada de px a nm

pixel_size = 127

n_bins = 10

x = data[1] * pixel_size
y = data[2] * pixel_size
sx = data[4] * pixel_size * np.sqrt(2 * np.log(2)) * 2
sy = data[5] * pixel_size * np.sqrt(2 * np.log(2)) * 2

minimo = 368
maximo = 482

condicion = sx <= maximo
condicion2 = sx >= minimo
sx = sx[condicion]
x = x[condicion]

sx = sx[condicion2]
x = x[condicion2]

print(len(sx))

# Function to fit a Gaussian distribution to data
def fit_gaussian(data):
    mu, std = norm.fit(data)
    return mu, std

mu_1 = fit_gaussian(sx)[0]
sigma_1 = fit_gaussian(sx)[1]


def gaussiana(x, mu, sigma):
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)

hist,bins=np.histogram(sx,density=True,bins=n_bins)
bin_centers = (bins[:-1] + bins[1:]) / 2


p,cov=curve_fit(gaussiana,bin_centers,hist,p0=(mu_1,sigma_1))
mu,sigma=p



FWHM = mu
#print(FWHM)
#print(2 * np.sqrt(2 * np.log(2)) * sigma)
print(mu)
print(sigma)
x=np.linspace(minimo - 10, maximo + 10, 100)
plt.close('all')
plt.grid(zorder = 1, alpha = 0.5)
plt.figure(1)
plt.xlabel("PSF FWHM [nm]")
plt.ylabel("Frecuencia")


#plt.plot(bin_centers,hist,'.')
plt.hist(sx, density = True , bins= n_bins, color = "lightgreen",  zorder = 2, edgecolor='forestgreen', linewidth=1.2)
plt.plot(x,gaussiana(x,mu,sigma), color='black', ls='dashed', label="Ajuste gaussiano")
plt.axvline(mu, color="black", ls=':', label="$\mu$")
plt.annotate(f'FWHM = {FWHM:.0f}', xy=(500, 0.01),
             fontsize=12)

plt.legend()
plt.show()

plt.savefig('foo.png')
plt.savefig('foo.pdf')
plt.show()
# Out:
# 305
# 418.8410338017614
# 17.037594699277594

# %% [markdown]
# ## Láser azul

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import curve_fit


n=[-15, -10, -8, -4, -2, -1, 0, 1, 2, 4, 8, 10, 15]



filename = "C:/Users/Usuario/Documents/Facultad/Laboratorio 7/PSF/azul_list_0_locs.txt"
data = pd.read_csv(filename, sep=" ", header=None)

#Data pasada de px a nm

pixel_size = 127

n_bins = 10

x = data[1] * pixel_size
y = data[2] * pixel_size
sx = data[4] * pixel_size
sy = data[5] * pixel_size


# Function to fit a Gaussian distribution to data
def fit_gaussian(data):
    mu, std = norm.fit(data)
    return mu, std

mu_1 = fit_gaussian(sx)[0]
sigma_1 = fit_gaussian(sx)[1]


def gaussiana(x, mu, sigma):
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)

hist,bins=np.histogram(sx,density=True,bins=n_bins)
bin_centers = (bins[:-1] + bins[1:]) / 2


p,cov=curve_fit(gaussiana,bin_centers,hist,p0=(mu_1,sigma_1))
mu,sigma=p



FWHM = 2 * np.sqrt(2 * np.log(2)) * mu
print(FWHM)
print(2 * np.sqrt(2 * np.log(2)) * sigma)
#print(mu)
#print(sigma)
# Out:
# 367.0536890139476
# 41.836121572082696

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import curve_fit


n=[-15, -10, -8, -4, -2, -1, 0, 1, 2, 4, 8, 10, 15]



filename = "C:/Users/Usuario/Documents/Facultad/Laboratorio 7/PSF/azul_list_0_locs.txt"
data = pd.read_csv(filename, sep=" ", header=None)

#Data pasada de px a nm

pixel_size = 127

n_bins = 7

x = data[1] * pixel_size
y = data[2] * pixel_size
sx = data[4] * pixel_size * np.sqrt(2 * np.log(2)) * 2
sy = data[5] * pixel_size * np.sqrt(2 * np.log(2)) * 2

minimo = 283
maximo = 451

print("minimo =", minimo)

condicion = sx <= maximo
condicion2 = sx >= minimo
sx = sx[condicion]
x = x[condicion]

sx = sx[condicion2]
x = x[condicion2]

print(len(sx))

# Function to fit a Gaussian distribution to data
def fit_gaussian(data):
    mu, std = norm.fit(data)
    return mu, std

mu_1 = fit_gaussian(sx)[0]
sigma_1 = fit_gaussian(sx)[1]


def gaussiana(x, mu, sigma):
    return 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)

hist,bins=np.histogram(sx,density=True,bins=n_bins)
bin_centers = (bins[:-1] + bins[1:]) / 2


p,cov=curve_fit(gaussiana,bin_centers,hist,p0=(mu_1,sigma_1))
mu,sigma=p



FWHM = mu
#print(FWHM)
#print(2 * np.sqrt(2 * np.log(2)) * sigma)
print(mu)
print(sigma)
x=np.linspace(minimo - 10, maximo + 10, 100)
plt.close('all')
plt.grid(zorder = 1, alpha = 0.5)
plt.figure(1)
plt.xlabel("PSF FWHM [nm]")
plt.ylabel("Frecuencia")


#plt.plot(bin_centers,hist,'.')
plt.hist(sx, density = True , bins= n_bins, color = "lightskyblue",  zorder = 2, edgecolor='royalblue', linewidth=1.2)
plt.plot(x,gaussiana(x,mu,sigma), color='black', ls='dashed', label="Ajuste gaussiano")
plt.axvline(mu, color="black", ls=':', label="$\mu$")
plt.annotate(f'FWHM = {FWHM:.0f}', xy=(500, 0.01),
             fontsize=12)

plt.legend()
plt.show()

plt.savefig('foo.png')
plt.savefig('foo.pdf')
plt.show()
# Out:
# minimo = 283
# 54
# 367.9111801383461
# 25.2951447024849
